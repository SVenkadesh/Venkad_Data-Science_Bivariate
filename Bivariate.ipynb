# %% [markdown]
# # Covariance

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      Unnamed: 0 gender    ssc_b    hsc_b     hsc_s   degree_t workex  \
# 0             0      M   Others   Others  Commerce   Sci&Tech     No
# 1             1      M  Central   Others   Science   Sci&Tech    Yes
# 2             2      M  Central  Central      Arts  Comm&Mgmt     No
# 3             3      M  Central  Central   Science   Sci&Tech     No
# 4             4      M  Central  Central  Commerce  Comm&Mgmt     No
# ..          ...    ...      ...      ...       ...        ...    ...
# 210         210      M   Others   Others  Commerce  Comm&Mgmt     No
# 211         211      M   Others   Others   Science   Sci&Tech     No
# 212         212      M   Others   Others  Commerce  Comm&Mgmt    Yes
# 213         213      F   Others   Others  Commerce  Comm&Mgmt     No
# 214         214      M  Central   Others   Science  Comm&Mgmt     No
#
#     specialisation      status  sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0        0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# dtype: int64

# %%
dataset.cov()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataset.cov()
#
# File ~\anaconda3\envs\aiml\Lib\site-packages\pandas\core\frame.py:11204, in DataFrame.cov(self, min_periods, ddof, numeric_only)
#   11202 cols = data.columns
#   11203 idx = cols.copy()
# > 11204 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11206 if notna(mat).all():
#   11207     if min_periods is not None and min_periods > len(mat):
#
# File ~\anaconda3\envs\aiml\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
dataset.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset.corr()
#
# File ~\anaconda3\envs\aiml\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\envs\aiml\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...
